# %%
print("Hello world")
# Out:
# Hello world

# %%
a=5

# %%
a=5; print(a)
# Out:
# 5

# %%
x=5;y=9; print(x+y)
# Out:
# 14

# %%
if(x==5):
    print("hello")
# Out:
# hello

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel("Y-axis")
plt.xlabel("X-axis")
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,6,8],'ro')
plt.axis([0,6,0,20])
plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
plt.plot([4,8,2,6])
plt.ylabel('Y-axis')
plt.show()

# %%
names = ['group-A','group-B','group-C']
values = ['180','170','190']
plt.subplot(131)
plt.bar(names,values)
plt.suptitle('Heights')
plt.show()
plt.savefig('heights.png',bbox_inches='tight')

# %%
# Out:
# 10

# %%
import numpy as np
a = np.array([1,3,54])
b = np.array([[1,3,4],[3,4,56]])
type(b)
# Out:
# numpy.ndarray
